# %%
import pandas as pd

# %%
data = pd.read_csv("./App/static/data/test_data.csv")
data.head()
# Out:
#     水域   大学名   クラス   チーム名  race1  race2  race3
# 0  北海道  北海道大  470級  北海道大A     14     63     27
# 1  北海道  北海道大  470級  北海道大B     68     52     44
# 2  北海道  北海道大  470級  北海道大C      8     41     59
# 3   東北   東北大  470級   東北大A      6     25     29
# 4   東北   東北大  470級   東北大B     16      8      3

# %%
class Item(object):
    def __init__(self, area, univname,boatclass, team, race1,race2,race3):
        self.area = area
        self.univname = univname
        self.boatclass = boatclass
        self.team = team
        self.race1 = race1
        self.race2 = race2
        self.race3 = race3

# %%
[Item(*row) for key, row, in  data.iterrows()]

# %%
data.iterrows
